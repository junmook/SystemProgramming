# %% [markdown]
# # Import modules

# %%
import keras
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Activation
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K
from keras.utils.vis_utils import model_to_dot
from IPython.display import SVG
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import pandas as pd
import seaborn as sns
#epoch, learning rate 변경하여 accuracy를 75%이상으로 증가시켜야함
#accuracy가 75%이상이면 코드 부분은 만점을 부여함
#모델을 분석하는 것이 더 중요하다.
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Tuning parameters

# %%
epochs = 50
learning_rate=0.01

# %%
batch_size = 32
num_classes = 10

# %% [markdown]
# # Data

# %% [markdown]
# ## Plot image

# %%
def plot_images(x, y_true, y_pred=None, size=(5, 5)):
    assert len(x) == len(y_true) == size[0] * size[1]
    
    fig, axes = plt.subplots(size[0], size[1])
    fig.subplots_adjust(hspace=0.1, wspace=0.1)

    for i, ax in enumerate(axes.flat):
        if x[i].shape[-1] == 1:
          ax.imshow(x[i].reshape(x[i].shape[0], x[i].shape[1]))
        else:
          ax.imshow(x[i])

        if y_pred is None:
            xlabel = "True: {0}".format(y_true[i].argmax())
        else:
            xlabel = "True: {0}, Pred: {1}".format(y_true[i].argmax(), 
                                                   y_pred[i].argmax())

        ax.set_xlabel(xlabel)
        
        ax.set_xticks([])
        ax.set_yticks([])

    plt.show()

# %% [markdown]
# ## Load dataset

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 20s 0us/step

# %% [markdown]
# ## Reshaping the data

# %%
if len(x_train.shape) < 4:
  x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], x_train.shape[2], 1)
  x_test = x_test.reshape(x_test.shape[0], x_train.shape[1], x_train.shape[2], 1)

# %%
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %% [markdown]
# ## Applying One hot encoding for the data

# %%
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %% [markdown]
# ## Show data

# %%
plot_images(x_train[:25], y_train[:25])

# %% [markdown]
# # Creating the DNN model

# %%
model = Sequential()

# %% [markdown]
# ## Adding layers to the model

# %%
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', 
                 input_shape=x_train.shape[1:]))
model.add(Conv2D(32, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))


model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %% [markdown]
# ## Visualization the model

# %%
SVG(model_to_dot(model, show_shapes=True).create(prog='dot', format='svg'))

# %% [markdown]
# ## Optimizer

# %%
optimizer = keras.optimizers.SGD(lr=learning_rate)

# %% [markdown]
# ## Compiling the model

# %%
model.compile(loss=keras.losses.categorical_crossentropy, 
              optimizer=optimizer, 
              metrics=['accuracy'])

# %% [markdown]
# ## Training the model

# %%
model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(x_test, y_test))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 23s 469us/step - loss: 2.1403 - acc: 0.1978 - val_loss: 2.0224 - val_acc: 0.2673
# Epoch 2/50
# 50000/50000 [==============================] - 18s 354us/step - loss: 1.8499 - acc: 0.3215 - val_loss: 1.6667 - val_acc: 0.3934
# Epoch 3/50
# 50000/50000 [==============================] - 18s 353us/step - loss: 1.6475 - acc: 0.3941 - val_loss: 1.4951 - val_acc: 0.4536
# Epoch 4/50
# 50000/50000 [==============================] - 18s 352us/step - loss: 1.5183 - acc: 0.4435 - val_loss: 1.3847 - val_acc: 0.4915
# Epoch 5/50
# 50000/50000 [==============================] - 18s 351us/step - loss: 1.4361 - acc: 0.4766 - val_loss: 1.3348 - val_acc: 0.5142
# Epoch 6/50
# 50000/50000 [==============================] - 18s 351us/step - loss: 1.3708 - acc: 0.5039 - val_loss: 1.2541 - val_acc: 0.5495
# Epoch 7/50
# 50000/50000 [==============================] - 18s 352us/step - loss: 1.3167 - acc: 0.5266 - val_loss: 1.2072 - val_acc: 0.5683
# Epoch 8/50
# 50000/50000 [==============================] - 18s 351us/step - loss: 1.2720 - acc: 0.5446 - val_loss: 1.1607 - val_acc: 0.5896
# Epoch 9/50
# 50000/50000 [==============================] - 17s 349us/step - loss: 1.2226 - acc: 0.5655 - val_loss: 1.2151 - val_acc: 0.5702
# Epoch 10/50
# 50000/50000 [==============================] - 17s 349us/step - loss: 1.1846 - acc: 0.5788 - val_loss: 1.2199 - val_acc: 0.5733
# Epoch 11/50
# 50000/50000 [==============================] - 17s 347us/step - loss: 1.1482 - acc: 0.5914 - val_loss: 1.0763 - val_acc: 0.6171
# Epoch 12/50
# 50000/50000 [==============================] - 17s 349us/step - loss: 1.1066 - acc: 0.6095 - val_loss: 1.0182 - val_acc: 0.6401
# Epoch 13/50
# 50000/50000 [==============================] - 17s 346us/step - loss: 1.0750 - acc: 0.6188 - val_loss: 1.0308 - val_acc: 0.6389
# Epoch 14/50
# 50000/50000 [==============================] - 17s 344us/step - loss: 1.0456 - acc: 0.6289 - val_loss: 0.9758 - val_acc: 0.6601
# Epoch 15/50
# 50000/50000 [==============================] - 17s 344us/step - loss: 1.0173 - acc: 0.6408 - val_loss: 0.9456 - val_acc: 0.6621
# Epoch 16/50
# 50000/50000 [==============================] - 17s 344us/step - loss: 0.9871 - acc: 0.6514 - val_loss: 0.9089 - val_acc: 0.6805
# Epoch 17/50
# 50000/50000 [==============================] - 17s 346us/step - loss: 0.9600 - acc: 0.6612 - val_loss: 0.8991 - val_acc: 0.6830
# Epoch 18/50
# 50000/50000 [==============================] - 17s 344us/step - loss: 0.9419 - acc: 0.6661 - val_loss: 0.8980 - val_acc: 0.6873
# Epoch 19/50
# 50000/50000 [==============================] - 17s 344us/step - loss: 0.9185 - acc: 0.6770 - val_loss: 0.8718 - val_acc: 0.6923
# Epoch 20/50
# 50000/50000 [==============================] - 17s 344us/step - loss: 0.8940 - acc: 0.6854 - val_loss: 0.8711 - val_acc: 0.6911
# Epoch 21/50
# 50000/50000 [==============================] - 17s 342us/step - loss: 0.8739 - acc: 0.6904 - val_loss: 0.8451 - val_acc: 0.7045
# Epoch 22/50
# 50000/50000 [==============================] - 17s 340us/step - loss: 0.8526 - acc: 0.6987 - val_loss: 0.8057 - val_acc: 0.7174
# Epoch 23/50
# 50000/50000 [==============================] - 17s 344us/step - loss: 0.8315 - acc: 0.7068 - val_loss: 0.8394 - val_acc: 0.7063
# Epoch 24/50
# 50000/50000 [==============================] - 17s 343us/step - loss: 0.8130 - acc: 0.7126 - val_loss: 0.7744 - val_acc: 0.7292
# Epoch 25/50
# 50000/50000 [==============================] - 17s 339us/step - loss: 0.7947 - acc: 0.7193 - val_loss: 0.7632 - val_acc: 0.7347
# Epoch 26/50
# 50000/50000 [==============================] - 17s 337us/step - loss: 0.7797 - acc: 0.7232 - val_loss: 0.8026 - val_acc: 0.7229
# Epoch 27/50
# 50000/50000 [==============================] - 17s 337us/step - loss: 0.7638 - acc: 0.7296 - val_loss: 0.7556 - val_acc: 0.7376
# Epoch 28/50
# 50000/50000 [==============================] - 17s 336us/step - loss: 0.7517 - acc: 0.7365 - val_loss: 0.7751 - val_acc: 0.7303
# Epoch 29/50
# 50000/50000 [==============================] - 17s 336us/step - loss: 0.7359 - acc: 0.7407 - val_loss: 0.7429 - val_acc: 0.7430
# Epoch 30/50
# 50000/50000 [==============================] - 17s 337us/step - loss: 0.7235 - acc: 0.7441 - val_loss: 0.7066 - val_acc: 0.7561
# Epoch 31/50
# 50000/50000 [==============================] - 17s 337us/step - loss: 0.7122 - acc: 0.7495 - val_loss: 0.7028 - val_acc: 0.7528
# Epoch 32/50
# 50000/50000 [==============================] - 17s 338us/step - loss: 0.6963 - acc: 0.7561 - val_loss: 0.7326 - val_acc: 0.7471
# Epoch 33/50
# 50000/50000 [==============================] - 17s 336us/step - loss: 0.6829 - acc: 0.7590 - val_loss: 0.6726 - val_acc: 0.7696
# Epoch 34/50
# 50000/50000 [==============================] - 17s 338us/step - loss: 0.6761 - acc: 0.7607 - val_loss: 0.6866 - val_acc: 0.7605
# Epoch 35/50
# 50000/50000 [==============================] - 17s 337us/step - loss: 0.6613 - acc: 0.7655 - val_loss: 0.6672 - val_acc: 0.7707
# Epoch 36/50
# 50000/50000 [==============================] - 17s 338us/step - loss: 0.6507 - acc: 0.7702 - val_loss: 0.6653 - val_acc: 0.7672
# Epoch 37/50
# 50000/50000 [==============================] - 17s 336us/step - loss: 0.6439 - acc: 0.7725 - val_loss: 0.6423 - val_acc: 0.7768
# Epoch 38/50
# 50000/50000 [==============================] - 17s 334us/step - loss: 0.6313 - acc: 0.7760 - val_loss: 0.6494 - val_acc: 0.7762
# Epoch 39/50
# 50000/50000 [==============================] - 17s 334us/step - loss: 0.6286 - acc: 0.7749 - val_loss: 0.6599 - val_acc: 0.7727
# Epoch 40/50
# 50000/50000 [==============================] - 17s 335us/step - loss: 0.6153 - acc: 0.7820 - val_loss: 0.6657 - val_acc: 0.7670
# Epoch 41/50
# 50000/50000 [==============================] - 17s 335us/step - loss: 0.5996 - acc: 0.7865 - val_loss: 0.6613 - val_acc: 0.7750
# Epoch 42/50
# 50000/50000 [==============================] - 17s 334us/step - loss: 0.5961 - acc: 0.7877 - val_loss: 0.6550 - val_acc: 0.7725
# Epoch 43/50
# 50000/50000 [==============================] - 17s 335us/step - loss: 0.5873 - acc: 0.7912 - val_loss: 0.6239 - val_acc: 0.7822
# Epoch 44/50
# 50000/50000 [==============================] - 17s 334us/step - loss: 0.5769 - acc: 0.7946 - val_loss: 0.6245 - val_acc: 0.7852
# Epoch 45/50
# 50000/50000 [==============================] - 17s 334us/step - loss: 0.5701 - acc: 0.7985 - val_loss: 0.6532 - val_acc: 0.7757
# Epoch 46/50
# 50000/50000 [==============================] - 17s 335us/step - loss: 0.5630 - acc: 0.8004 - val_loss: 0.6325 - val_acc: 0.7838
# Epoch 47/50
# 50000/50000 [==============================] - 17s 334us/step - loss: 0.5546 - acc: 0.8031 - val_loss: 0.6409 - val_acc: 0.7798
# Epoch 48/50
# 50000/50000 [==============================] - 17s 335us/step - loss: 0.5492 - acc: 0.8037 - val_loss: 0.6237 - val_acc: 0.7839
# Epoch 49/50
# 50000/50000 [==============================] - 17s 334us/step - loss: 0.5450 - acc: 0.8050 - val_loss: 0.6083 - val_acc: 0.7906
# Epoch 50/50
# 50000/50000 [==============================] - 17s 336us/step - loss: 0.5351 - acc: 0.8110 - val_loss: 0.6063 - val_acc: 0.7885

# %% [markdown]
# ## Evaulating the model

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.6062571105003357
# Test accuracy: 0.7885

# %% [markdown]
# ## Prediction the model

# %%
y_pred = model.predict(x_test)

# %%
plot_images(x=x_test[:25], y_true=y_test[:25], y_pred=y_pred[:25])

# %%
y_result = confusion_matrix(y_test.argmax(axis=1), y_pred.argmax(axis=1))
sns.heatmap(pd.DataFrame(y_result, range(10), range(10)), annot=True, fmt='g')
